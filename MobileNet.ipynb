# %% [markdown]
# <a href="https://colab.research.google.com/github/venkat2ram/Keras-and-Tensorflow/blob/master/MobileNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense,Activation
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import categorical_crossentropy
from sklearn.metrics import confusion_matrix
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications import imagenet_utils
import itertools
import os
import shutil
import random
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def prepareImage(file):
  img_path='/content/'
  img=image.load_img(img_path+file, target_size=(224,224))
  img_array=image.img_to_array(img)
  img_array_expanded_dims=np.expand_dims(img_array,axis=0)
  return tf.keras.applications.mobilenet.preprocess_input(img_array_expanded_dims)

# %%
mobile=tf.keras.applications.mobilenet.MobileNet()
# Out:
# ...
# 17227776/17225924 [==============================] - 0s 0us/step

# %%
from IPython.display import Image
Image(filename='/content/6845398883_83b39c434f_b.png')

# %%
prepared_image=prepareImage('6845398883_83b39c434f_b.png')
predictions=mobile.predict(prepared_image)

# %%
results=imagenet_utils.decode_predictions(predictions)
# Out:
# ...
# 40960/35363 [==================================] - 0s 0us/step

# %%
results
# Out:
# [[('n01820546', 'lorikeet', 0.6364509),
#   ('n01818515', 'macaw', 0.07534756),
#   ('n01843383', 'toucan', 0.070152655),
#   ('n02607072', 'anemone_fish', 0.045099825),
#   ('n04409515', 'tennis_ball', 0.028086215)]]

# %%
Image(filename='/content/hqdefault.png')

# %%
prepared_image=prepareImage('hqdefault.png')
predictions=mobile.predict(prepared_image)

# %%
results=imagenet_utils.decode_predictions(predictions)

# %%
results
# Out:
# [[('n02326432', 'hare', 0.38216558),
#   ('n02356798', 'fox_squirrel', 0.26449782),
#   ('n01877812', 'wallaby', 0.15756154),
#   ('n02487347', 'macaque', 0.10273475),
#   ('n02325366', 'wood_rabbit', 0.06971616)]]
